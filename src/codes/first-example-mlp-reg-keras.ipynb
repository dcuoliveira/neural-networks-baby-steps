# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np

import tensorflow as tf
from tensorflow import keras

from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

plt.style.use('bmh')
plt.rcParams["figure.figsize"] = (15, 10)

# %%
scaler = StandardScaler() 
housing = fetch_california_housing()

# %% [markdown]
# ## Building a Regression MLP Using the Sequential API - Géron (2019)
#
# We follow example 2 in this repository to build our first MLP model for a regression task.
#
# We consider the task of predicting the ln(median house value), named "MedHouseVal", using the numerical features at our disposal. Below you will find some summary statistics of the dataset.

# %%
y = pd.DataFrame(housing['target'], columns=housing['target_names'])
X = pd.DataFrame(housing['data'], columns=housing['feature_names'])
data = pd.concat([y, X], axis=1)

data.head()
# Out:
#    MedHouseVal  MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# 0        4.526  8.3252      41.0  6.984127   1.023810       322.0  2.555556
# 1        3.585  8.3014      21.0  6.238137   0.971880      2401.0  2.109842
# 2        3.521  7.2574      52.0  8.288136   1.073446       496.0  2.802260
# 3        3.413  5.6431      52.0  5.817352   1.073059       558.0  2.547945
# 4        3.422  3.8462      52.0  6.281853   1.081081       565.0  2.181467
#
#    Latitude  Longitude
# 0     37.88    -122.23
# 1     37.86    -122.22
# 2     37.85    -122.24
# 3     37.85    -122.25
# 4     37.85    -122.25

# %%
data.describe()
# Out:
#         MedHouseVal        MedInc      HouseAge      AveRooms     AveBedrms  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       2.068558      3.870671     28.639486      5.429000      1.096675
# std        1.153956      1.899822     12.585558      2.474173      0.473911
# min        0.149990      0.499900      1.000000      0.846154      0.333333
# 25%        1.196000      2.563400     18.000000      4.440716      1.006079
# 50%        1.797000      3.534800     29.000000      5.229129      1.048780
# 75%        2.647250      4.743250     37.000000      6.052381      1.099526
# max        5.000010     15.000100     52.000000    141.909091     34.066667
#
#          Population      AveOccup      Latitude     Longitude
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean    1425.476744      3.070655     35.631861   -119.569704
# std     1132.462122     10.386050      2.135952      2.003532
# min        3.000000      0.692308     32.540000   -124.350000
# 25%      787.000000      2.429741     33.930000   -121.800000
# 50%     1166.000000      2.818116     34.260000   -118.490000
# 75%     1725.000000      3.282261     37.710000   -118.010000
# max    35682.000000   1243.333333     41.950000   -114.310000

# %%
data.plot.scatter(y='MedHouseVal', x='MedInc')
# Out:
# <AxesSubplot:xlabel='MedInc', ylabel='MedHouseVal'>

# %% [markdown]
# ### Data preprocessing
#
# The dataset is all composed of numerical fetures and there is no missing value on the dataset. To make it easier for the optimization algorithm to converge to the global minimum of the loss function, we use the "StandardScaler" function on the dataset in order to take the zscore score of the vairbles.
#
# More specifically, the "StandardScaler" function computes the mean and standard deviation of the considered dataset (i.e. "X_train") and stores it to later apply on further datasets (i.e. "X_valid" and/or "X_test").

# %%
X_train_full, X_test, y_train_full, y_test = train_test_split(housing.data, housing.target) 
X_train, X_valid, y_train, y_valid = train_test_split(X_train_full, y_train_full) 

X_train_scaled = scaler.fit_transform(X_train) 
X_valid_scaled = scaler.transform(X_valid) 
X_test_scaled = scaler.transform(X_test)

# %%
pd.DataFrame(X_train).mean()
# Out:
# 0       3.851515
# 1      28.578381
# 2       5.447788
# 3       1.102439
# 4    1430.882946
# 5       3.122896
# 6      35.635415
# 7    -119.568788
# dtype: float64

# %%
pd.DataFrame(X_train).std()
# Out:
# 0       1.889664
# 1      12.623681
# 2       2.834440
# 3       0.557261
# 4    1127.382692
# 5      12.625646
# 6       2.129521
# 7       2.004998
# dtype: float64

# %%
(X_valid[:,0] - pd.DataFrame(X_train).mean()[0]) / pd.DataFrame(X_train).std()[0]
# Out:
# array([ 0.97476866,  0.2770255 , -1.08157595, ..., -0.34038591,
#        -0.10150744, -0.08441445])

# %%
X_valid_scaled[:,0]
# Out:
# array([ 0.97481064,  0.27703743, -1.08162253, ..., -0.34040057,
#        -0.10151181, -0.08441809])

# %% [markdown]
# ### Model setup
#
# Once again we will use the keras "Sequential" function to build our feed forward neural network model.
#
# One easier choice we would make is to have only one hidden unit in the output layer. This is the case because we want to forecast one continuous vairable. Furthermore, since our target variable is continuos, we need a loss function which enables the comparison of continuous values. The most common choice is the "mean_squared_error". The other hyperparemeters of the model could be changed in order to make a better model.

# %%
model = keras.models.Sequential(
    [
        keras.layers.Dense(30, activation="relu", input_shape=X_train.shape[1:]),
        keras.layers.Dense(1) 
    ]
)

model.compile(loss="mean_squared_error",
              optimizer="sgd") 
history = model.fit(X_train_scaled, y_train, epochs=20, validation_data=(X_valid_scaled, y_valid))
# Out:
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/20
# 11610/11610 [==============================] - 1s 66us/sample - loss: 0.7575 - val_loss: 0.6041
# Epoch 2/20
# 11610/11610 [==============================] - 0s 29us/sample - loss: 0.5837 - val_loss: 1.2608
# Epoch 3/20
# 11610/11610 [==============================] - 0s 29us/sample - loss: 0.6048 - val_loss: 0.4807
# Epoch 4/20
# 11610/11610 [==============================] - 0s 29us/sample - loss: 0.4582 - val_loss: 0.4677
# Epoch 5/20
# 11610/11610 [==============================] - 0s 29us/sample - loss: 0.4424 - val_loss: 0.4587
# Epoch 6/20
# 11610/11610 [==============================] - 0s 29us/sample - loss: 0.4396 - val_loss: 0.5011
# Epoch 7/20
# 11610/11610 [==============================] - 0s 29us/sample - loss: 0.4336 - val_loss: 0.4448
# Epoch 8/20
# 11610/11610 [==============================] - 0s 29us/sample - loss: 0.4215 - val_loss: 0.4375
# Epoch 9/20
# 11610/11610 [==============================] - 0s 29us/sample - loss: 0.4130 - val_loss: 0.4307
# Epoch 10/20
# 11610/11610 [==============================] - 0s 29us/sample - loss: 0.4074 - val_loss: 0.4263
# Epoch 11/20
# 11610/11610 [==============================] - 0s 29us/sample - loss: 0.4108 - val_loss: 0.4251
# Epoch 12/20
# 11610/11610 [==============================] - 0s 30us/sample - loss: 0.4008 - val_loss: 0.4181
# Epoch 13/20
# 11610/11610 [==============================] - 0s 29us/sample - loss: 0.3981 - val_loss: 0.4177
# Epoch 14/20
# 11610/11610 [==============================] - 0s 29us/sample - loss: 0.3930 - val_loss: 0.4140
# Epoch 15/20
# 11610/11610 [==============================] - 0s 29us/sample - loss: 0.3891 - val_loss: 0.4065
# Epoch 16/20
# 11610/11610 [==============================] - 0s 29us/sample - loss: 0.3866 - val_loss: 0.4042
# Epoch 17/20
# 11610/11610 [==============================] - 0s 29us/sample - loss: 0.3907 - val_loss: 0.4048
# Epoch 18/20
# 11610/11610 [==============================] - 0s 29us/sample - loss: 0.3865 - val_loss: 0.4038
# Epoch 19/20
# 11610/11610 [==============================] - 0s 29us/sample - loss: 0.3859 - val_loss: 0.3979
# Epoch 20/20
# 11610/11610 [==============================] - 0s 30us/sample - loss: 0.3819 - val_loss: 0.3961

# %%
mse_test = model.evaluate(X_test_scaled, y_test)
X_new = X_test[:3] # pretend these are new instances
y_pred = model.predict(X_new)
# Out:
# 5160/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...

# %%
y_pred
# Out:
# array([[1.3534782],
#        [1.9248536],
#        [1.4361196]], dtype=float32)

# %%
y_test[:3]
# Out:
# array([1.285, 1.335, 1.286])

# %%
pd.DataFrame(history.history).plot()
# Out:
# <AxesSubplot:>
